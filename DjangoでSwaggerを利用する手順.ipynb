# %% [markdown]
# DjangoでSwaggerを利用してAPI設計書兼テストツールとして活用する手順は以下のとおりです。
#
# **1. 必要なパッケージのインストール**
#
# 以下のパッケージをインストールします。
#
# * `drf-spectacular`: OpenAPIスキーマの自動生成
# * `djangorestframework`: RESTful API構築のためのフレームワーク
#
# ```bash
# pip install drf-spectacular djangorestframework
# ```
#
# **2. Djangoプロジェクトの設定**
#
# `settings.py`に以下の設定を追加します。

# %%
INSTALLED_APPS = [
    # ...
    'rest_framework',
    'drf_spectacular',
]

REST_FRAMEWORK = {
    'DEFAULT_SCHEMA_CLASS': 'drf_spectacular.openapi.AutoSchema',
}

SPECTACULAR_SETTINGS = {
    'TITLE': 'Your Project API',
    'DESCRIPTION': 'Your project description',
    'VERSION': '1.0.0',
}

# %% [markdown]
# **3. URLの設定**
#
# `urls.py`に以下の設定を追加します。

# %%
from django.urls import path
from drf_spectacular.views import SpectacularAPIView, SpectacularSwaggerView

urlpatterns = [
    # ...
    path('api/schema/', SpectacularAPIView.as_view(), name='schema'),
    path('api/schema/swagger-ui/', SpectacularSwaggerView.as_view(url_name='schema'), name='swagger-ui'),
]

# %% [markdown]
# **4. APIビューの作成**
#
# `views.py`にAPIビューを作成します。

# %%
from rest_framework import viewsets
from .models import YourModel
from .serializers import YourModelSerializer

class YourModelViewSet(viewsets.ModelViewSet):
    queryset = YourModel.objects.all()
    serializer_class = YourModelSerializer

# %% [markdown]
# **5. シリアライザの作成**
#
# `serializers.py`にシリアライザを作成します。

# %%
from rest_framework import serializers
from .models import YourModel

class YourModelSerializer(serializers.ModelSerializer):
    class Meta:
        model = YourModel
        fields = '__all__'

# %% [markdown]
# **6. モデルの作成**
#
# `models.py`にモデルを作成します。

# %%
from django.db import models

class YourModel(models.Model):
    name = models.CharField(max_length=255)
    description = models.TextField()

# %% [markdown]
# **7. マイグレーションの実行**
#
# 以下のコマンドを実行して、データベースのマイグレーションを行います。
#
# ```bash
# python manage.py makemigrations
# python manage.py migrate
# ```
#
# **8. Swagger UIへのアクセス**
#
# ブラウザで`http://127.0.0.1:8000/api/schema/swagger-ui/`にアクセスすると、Swagger UIが表示されます。
#
# **参考サイト**
#
# * DjangoでSwaggerUIを使おう！設定方法を徹底解説 - Qiita: [https://stackoverflow.com/questions/76606307/collecting-static-of-swagger-ui-in-django-project-on-server](https://stackoverflow.com/questions/76606307/collecting-static-of-swagger-ui-in-django-project-on-server)
# * DjangoRestFrameworkのコードからSwaggerドキュメントを生成しAPI設計を共有 - Qiita: [https://www.reddit.com/r/django/comments/12x52sd/swagger_for_django_api/](https://www.reddit.com/r/django/comments/12x52sd/swagger_for_django_api/)
# * Django REST FrameworkでのAPI実装からSwagger UIでスキーマを表示してみた - Zenn: [https://medium.com/@ukemeboswilson/creating-swagger-documentation-in-django-rest-framework-a-guide-to-drf-yasg-and-drf-spectacular-216fc41d47de](https://medium.com/@ukemeboswilson/creating-swagger-documentation-in-django-rest-framework-a-guide-to-drf-yasg-and-drf-spectacular-216fc41d47de)
#
# これらの手順と参考サイトを参考に、DjangoでSwaggerを活用して効率的なAPI開発を行ってください。

# %% [markdown]
# <div class="md-recitation">
#   Sources
#   <ol>
#   <li><a href="https://github.com/gersom911/api-task">https://github.com/gersom911/api-task</a></li>
#   <li><a href="https://github.com/voinovVladyslav/botanical-garden-api">https://github.com/voinovVladyslav/botanical-garden-api</a> subject to MIT</li>
#   <li><a href="https://medium.com/nerd-for-tech/django-rest-api-swagger-using-drf-and-ml-with-celery-for-an-iot-use-case-e47a8b8e927a">https://medium.com/nerd-for-tech/django-rest-api-swagger-using-drf-and-ml-with-celery-for-an-iot-use-case-e47a8b8e927a</a></li>
#   <li><a href="https://github.com/infantista/ProjectAPI">https://github.com/infantista/ProjectAPI</a></li>
#   <li><a href="https://github.com/ClaudiuLBS/django-rest-template">https://github.com/ClaudiuLBS/django-rest-template</a></li>
#   <li><a href="https://github.com/30096ompratap/Tasks">https://github.com/30096ompratap/Tasks</a></li>
#   <li><a href="https://github.com/sajjadrahman56/Learn-MLOPs">https://github.com/sajjadrahman56/Learn-MLOPs</a></li>
#   </ol>
# </div>
